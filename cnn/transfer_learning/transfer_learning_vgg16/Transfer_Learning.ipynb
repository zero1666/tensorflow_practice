# %% [markdown]
# # Transfer Learning
#
# Most of the time you won't want to train a whole convolutional network yourself. Modern ConvNets training on huge datasets like ImageNet take weeks on multiple GPUs. Instead, most people use a pretrained network either as a fixed feature extractor, or as an initial network to fine tune. In this notebook, you'll be using [VGGNet](https://arxiv.org/pdf/1409.1556.pdf) trained on the [ImageNet dataset](http://www.image-net.org/) as a feature extractor. Below is a diagram of the VGGNet architecture.
#
# <img src="assets/cnnarchitecture.jpg" width=700px>
#
# VGGNet is great because it's simple and has great performance, coming in second in the ImageNet competition. The idea here is that we keep all the convolutional layers, but replace the final fully connected layers with our own classifier. This way we can use VGGNet as a feature extractor for our images then easily train a simple classifier on top of that. What we'll do is take the first fully connected layer with 4096 units, including thresholding with ReLUs. We can use those values as a code for each image, then build a classifier on top of those codes.
#
# You can read more about transfer learning from [the CS231n course notes](http://cs231n.github.io/transfer-learning/#tf).
#
# ## Pretrained VGGNet
#
# We'll be using a pretrained network from https://github.com/machrisaa/tensorflow-vgg. Make sure to clone this repository to the directory you're working from. You'll also want to rename it so it has an underscore instead of a dash.
#
# ```
# git clone https://github.com/machrisaa/tensorflow-vgg.git tensorflow_vgg
# ```
#
# This is a really nice implementation of VGGNet, quite easy to work with. The network has already been trained and the parameters are available from this link. **You'll need to clone the repo into the folder containing this notebook.** Then download the parameter file using the next cell.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm

vgg_dir = 'tensorflow_vgg/'
# Make sure vgg exists
if not isdir(vgg_dir):
    raise Exception("VGG directory doesn't exist!")

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(vgg_dir + "vgg16.npy"):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='VGG16 Parameters') as pbar:
        urlretrieve(
            'https://s3.amazonaws.com/content.udacity-data.com/nd101/vgg16.npy',
            vgg_dir + 'vgg16.npy',
            pbar.hook)
else:
    print("Parameter file already exists!")
# Out:
# Parameter file already exists!

# %% [markdown]
# ## Flower power
#
# Here we'll be using VGGNet to classify images of flowers. To get the flower dataset, run the cell below. This dataset comes from the [TensorFlow inception tutorial](https://www.tensorflow.org/tutorials/image_retraining).

# %%
import tarfile

dataset_folder_path = 'flower_photos'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('flower_photos.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='Flowers Dataset') as pbar:
        urlretrieve(
            'http://download.tensorflow.org/example_images/flower_photos.tgz',
            'flower_photos.tar.gz',
            pbar.hook)

if not isdir(dataset_folder_path):
    with tarfile.open('flower_photos.tar.gz') as tar:
        tar.extractall()
        tar.close()

# %% [markdown]
# ## ConvNet Codes
#
# Below, we'll run through all the images in our dataset and get codes for each of them. That is, we'll run the images through the VGGNet convolutional layers and record the values of the first fully connected layer. We can then write these to a file for later when we build our own classifier.
#
# Here we're using the `vgg16` module from `tensorflow_vgg`. The network takes images of size $224 \times 224 \times 3$ as input. Then it has 5 sets of convolutional layers. The network implemented here has this structure (copied from [the source code](https://github.com/machrisaa/tensorflow-vgg/blob/master/vgg16.py)):
#
# ```
# self.conv1_1 = self.conv_layer(bgr, "conv1_1")
# self.conv1_2 = self.conv_layer(self.conv1_1, "conv1_2")
# self.pool1 = self.max_pool(self.conv1_2, 'pool1')
#
# self.conv2_1 = self.conv_layer(self.pool1, "conv2_1")
# self.conv2_2 = self.conv_layer(self.conv2_1, "conv2_2")
# self.pool2 = self.max_pool(self.conv2_2, 'pool2')
#
# self.conv3_1 = self.conv_layer(self.pool2, "conv3_1")
# self.conv3_2 = self.conv_layer(self.conv3_1, "conv3_2")
# self.conv3_3 = self.conv_layer(self.conv3_2, "conv3_3")
# self.pool3 = self.max_pool(self.conv3_3, 'pool3')
#
# self.conv4_1 = self.conv_layer(self.pool3, "conv4_1")
# self.conv4_2 = self.conv_layer(self.conv4_1, "conv4_2")
# self.conv4_3 = self.conv_layer(self.conv4_2, "conv4_3")
# self.pool4 = self.max_pool(self.conv4_3, 'pool4')
#
# self.conv5_1 = self.conv_layer(self.pool4, "conv5_1")
# self.conv5_2 = self.conv_layer(self.conv5_1, "conv5_2")
# self.conv5_3 = self.conv_layer(self.conv5_2, "conv5_3")
# self.pool5 = self.max_pool(self.conv5_3, 'pool5')
#
# self.fc6 = self.fc_layer(self.pool5, "fc6")
# self.relu6 = tf.nn.relu(self.fc6)
# ```
#
# So what we want are the values of the first fully connected layer, after being ReLUd (`self.relu6`). To build the network, we use
#
# ```
# with tf.Session() as sess:
#     vgg = vgg16.Vgg16()
#     input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
#     with tf.name_scope("content_vgg"):
#         vgg.build(input_)
# ```
#
# This creates the `vgg` object, then builds the graph with `vgg.build(input_)`. Then to get the values from the layer,
#
# ```
# feed_dict = {input_: images}
# codes = sess.run(vgg.relu6, feed_dict=feed_dict)
# ```

# %%
import os

import numpy as np
import tensorflow as tf

from tensorflow_vgg import vgg16
from tensorflow_vgg import utils

# %%
data_dir = 'flower_photos/'
contents = os.listdir(data_dir)
#print(contents)
classes = [each for each in contents if os.path.isdir(data_dir + each)]
#print(classes)

# %% [markdown]
# Below I'm running images through the VGG network in batches.
#
# > **Exercise:** Below, build the VGG network. Also get the codes from the first fully connected layer (make sure you get the ReLUd values).

# %%
# Set the batch size higher if you can fit in in your GPU memory
batch_size = 5
codes_list = []
labels = []
batch = []

codes = None

with tf.Session() as sess:
    
    # TODO: Build the vgg network here
    vgg = vgg16.Vgg16()
    input_ = tf.placeholder(tf.float32, [None, 224,224, 3])
    with tf.name_scope("content_vgg"):
        vgg.build(input_)

    for each in classes:
        print("Starting {} images".format(each))
        class_path = data_dir + each
        files = os.listdir(class_path)
        #print(class_path, "files first 5: ", files[0:5])
        for ii, file in enumerate(files, 1):
            # Add images to the current batch
            # utils.load_image crops the input images for us, from the center
            img = utils.load_image(os.path.join(class_path, file))
            batch.append(img.reshape((1, 224, 224, 3)))
            labels.append(each)
            
            # Running the batch through the network to get the codes
            if ii % batch_size == 0 or ii == len(files):
                
                # Image batch to pass to VGG network
                images = np.concatenate(batch)
                print("images.shape", images.shape, "batch.shape", np.array(batch).shape)
                
                # TODO: Get the values from the relu6 layer of the VGG network
                feed_dict ={input_: images}
                codes_batch = sess.run(vgg.relu6, feed_dict=feed_dict)
                
                # Here I'm building an array of the codes
                if codes is None:
                    codes = codes_batch
                else:
                    codes = np.concatenate((codes, codes_batch))
                
                # Reset to start building the next batch
                batch = []
                print('{} images processed'.format(ii))
# Out:
# /home/ww/workspace/DL/udacity/transfer-learning/tensorflow_vgg/vgg16.npy
# npy file loaded
# build model started
# build model finished: 0s
# Starting daisy images
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# 5 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 10 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 15 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 20 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 25 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 30 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 35 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 40 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 45 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 50 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 55 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 60 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 65 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 70 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 75 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 80 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 85 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 90 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 95 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 100 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 105 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 110 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 115 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 120 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 125 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 130 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 135 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 140 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 145 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 150 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 155 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 160 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 165 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 170 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 175 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# ...
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 645 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 650 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 655 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 660 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 665 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 670 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 675 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 680 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 685 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 690 images processed
# images.shape (5, 224, 224, 3) batch.shape (5, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 695 images processed
# images.shape (4, 224, 224, 3) batch.shape (4, 1, 224, 224, 3)
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 699 images processed

# %%
# write codes to file
with open('codes', 'w') as f:
    codes.tofile(f)
    
# write labels to file
import csv
with open('labels', 'w') as f:
    writer = csv.writer(f, delimiter='\n')
    writer.writerow(labels)

# %% [markdown]
# ## Building the Classifier
#
# Now that we have codes for all the images, we can build a simple classifier on top of them. The codes behave just like normal input into a simple neural network. Below I'm going to have you do most of the work.

# %%
# read codes and labels from file
import csv

with open('labels') as f:
    reader = csv.reader(f, delimiter='\n')
    labels = np.array([each for each in reader]).squeeze()
with open('codes') as f:
    codes = np.fromfile(f, dtype=np.float32)
    print("codes.shape", codes.shape)
    codes = codes.reshape((len(labels), -1))
# Out:
# codes.shape (15032320,)

# %%
print("codes.shape", codes.shape)
print("labels", labels.shape)
# Out:
# codes.shape (3670, 4096)
# labels (3670,)

# %% [markdown]
# ### Data prep
#
# As usual, now we need to one-hot encode our labels and create validation/test sets. First up, creating our labels!
#
# > **Exercise:** From scikit-learn, use [LabelBinarizer](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelBinarizer.html) to create one-hot encoded vectors from the labels.

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(labels)
labels_vecs = lb.transform(labels)# Your one-hot encoded labels array here

# %%
print(type(labels_vecs), "labels_vecs", labels_vecs.shape)
# Out:
# <class 'numpy.ndarray'> labels_vecs (3670, 5)

# %% [markdown]
# Now you'll want to create your training, validation, and test sets. An important thing to note here is that our labels and data aren't randomized yet. We'll want to shuffle our data so the validation and test sets contain data from all classes. Otherwise, you could end up with testing sets that are all one class. Typically, you'll also want to make sure that each smaller set has the same the distribution of classes as it is for the whole data set. The easiest way to accomplish both these goals is to use [`StratifiedShuffleSplit`](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedShuffleSplit.html) from scikit-learn.
#
# You can create the splitter like so:
# ```
# ss = StratifiedShuffleSplit(n_splits=1, test_size=0.2)
# ```
# Then split the data with
# ```
# splitter = ss.split(x, y)
# ```
#
# `ss.split` returns a generator of indices. You can pass the indices into the arrays to get the split sets. The fact that it's a generator means you either need to iterate over it, or use `next(splitter)` to get the indices. Be sure to read the [documentation](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedShuffleSplit.html) and the [user guide](http://scikit-learn.org/stable/modules/cross_validation.html#random-permutations-cross-validation-a-k-a-shuffle-split).
#
# > **Exercise:** Use StratifiedShuffleSplit to split the codes and labels into training, validation, and test sets.

# %%
from sklearn.model_selection import StratifiedShuffleSplit
ss =  StratifiedShuffleSplit(n_splits=1, test_size=0.2)
train_idx, val_idx = next(ss.split(codes, labels_vecs))
print(train_idx[:5], (val_idx)[:5])
half_val_idx = int(len(val_idx)/2)
val_idx, test_idx = val_idx[: half_val_idx], val_idx[half_val_idx:]

train_x, train_y = codes[train_idx],labels_vecs[train_idx]
val_x, val_y = codes[val_idx], labels_vecs[val_idx]
test_x, test_y =  codes[test_idx], labels_vecs[test_idx]
# Out:
# [ 971 1665 1864  115  528] [3408 1390 1396 2381  678]

# %%
print("Train shapes (x, y):", train_x.shape, train_y.shape)
print("Validation shapes (x, y):", val_x.shape, val_y.shape)
print("Test shapes (x, y):", test_x.shape, test_y.shape)
# Out:
# Train shapes (x, y): (2936, 4096) (2936, 5)
# Validation shapes (x, y): (367, 4096) (367, 5)
# Test shapes (x, y): (367, 4096) (367, 5)

# %% [markdown]
# If you did it right, you should see these sizes for the training sets:
#
# ```
# Train shapes (x, y): (2936, 4096) (2936, 5)
# Validation shapes (x, y): (367, 4096) (367, 5)
# Test shapes (x, y): (367, 4096) (367, 5)
# ```

# %% [markdown]
# ### Classifier layers
#
# Once you have the convolutional codes, you just need to build a classfier from some fully connected layers. You use the codes as the inputs and the image labels as targets. Otherwise the classifier is a typical neural network.
#
# > **Exercise:** With the codes and labels loaded, build the classifier. Consider the codes as your inputs, each of them are 4096D vectors. You'll want to use a hidden layer and an output layer as your classifier. Remember that the output layer needs to have one unit for each class and a softmax activation function. Use the cross entropy to calculate the cost.

# %%
inputs_ = tf.placeholder(tf.float32, shape=[None, codes.shape[1]])
labels_ = tf.placeholder(tf.int64, shape=[None, labels_vecs.shape[1]])

# TODO: Classifier layers and operations
fc = tf.contrib.layers.fully_connected(inputs_, 256)
logits = tf.contrib.layers.fully_connected(fc, labels_vecs.shape[1],activation_fn=None)# output layer logits
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=labels_, logits=logits))# cross entropy loss

optimizer = tf.train.AdamOptimizer().minimize(cost)# training optimizer

# Operations for validation/test accuracy
predicted = tf.nn.softmax(logits)
correct_pred = tf.equal(tf.argmax(predicted, 1), tf.argmax(labels_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %% [markdown]
# ### Batches!
#
# Here is just a simple way to do batches. I've written it so that it includes all the data. Sometimes you'll throw out some data at the end to make sure you have full batches. Here I just extend the last batch to include the remaining data.

# %%
def get_batches(x, y, n_batches=10):
    """ Return a generator that yields batches from arrays x and y. """
    batch_size = len(x)//n_batches
    
    for ii in range(0, n_batches*batch_size, batch_size):
        # If we're not on the last batch, grab data with size batch_size
        if ii != (n_batches-1)*batch_size:
            X, Y = x[ii: ii+batch_size], y[ii: ii+batch_size] 
        # On the last batch, grab the rest of the data
        else:
            X, Y = x[ii:], y[ii:]
        # I love generators
        yield X, Y

# %% [markdown]
# ### Training
#
# Here, we'll train the network.
#
# > **Exercise:** So far we've been providing the training code for you. Here, I'm going to give you a bit more of a challenge and have you write the code to train the network. Of course, you'll be able to see my solution if you need help. Use the `get_batches` function I wrote before to get your batches like `for x, y in get_batches(train_x, train_y)`. Or write your own!

# %%
epoches = 10
n_batch= 10
display_iter = 5
iteration = 0
saver = tf.train.Saver()

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(epoches):
        for x, y in get_batches(train_x, train_y, n_batch):
            feed_dict = {inputs_: x, labels_: y}
            loss, _ = sess.run([cost,optimizer], feed_dict=feed_dict)
            iteration += 1
            
            if iteration%display_iter == 0:
                print("Epoch:{}/{}".format(i+1, epoches), "Iteration {}/{}".format(iteration, n_batch), "Training loss is : {}".format(loss))
                feed = {inputs_: val_x, labels_: val_y}
                val_accu = sess.run(accuracy, feed_dict=feed)
                print("Epoch:{}/{}".format(i+1, epoches), "Iteration {}".format(iteration), "Validation Accuracy is : {}".format(val_accu))
        iteration = 0
    saver.save(sess, "checkpoints/flowers.ckpt")
# Out:
# Epoch:1/100 Iteration 5/10 Training loss is : 3.970165729522705
# Epoch:1/100 Iteration 5 Validation Accuracy is : 0.20980925858020782
# Epoch:1/100 Iteration 10/10 Training loss is : 3.596930742263794
# Epoch:1/100 Iteration 10 Validation Accuracy is : 0.20708446204662323
# Epoch:2/100 Iteration 5/10 Training loss is : 3.8344967365264893
# Epoch:2/100 Iteration 5 Validation Accuracy is : 0.20980925858020782
# Epoch:2/100 Iteration 10/10 Training loss is : 3.4692652225494385
# Epoch:2/100 Iteration 10 Validation Accuracy is : 0.21525885164737701
# Epoch:3/100 Iteration 5/10 Training loss is : 3.710814952850342
# Epoch:3/100 Iteration 5 Validation Accuracy is : 0.2234332412481308
# Epoch:3/100 Iteration 10/10 Training loss is : 3.3527541160583496
# Epoch:3/100 Iteration 10 Validation Accuracy is : 0.2261580377817154
# Epoch:4/100 Iteration 5/10 Training loss is : 3.5957343578338623
# Epoch:4/100 Iteration 5 Validation Accuracy is : 0.2288828343153
# Epoch:4/100 Iteration 10/10 Training loss is : 3.245337963104248
# Epoch:4/100 Iteration 10 Validation Accuracy is : 0.23160763084888458
# Epoch:5/100 Iteration 5/10 Training loss is : 3.4880030155181885
# Epoch:5/100 Iteration 5 Validation Accuracy is : 0.23160763084888458
# Epoch:5/100 Iteration 10/10 Training loss is : 3.1461751461029053
# Epoch:5/100 Iteration 10 Validation Accuracy is : 0.23160763084888458
# Epoch:6/100 Iteration 5/10 Training loss is : 3.387115478515625
# Epoch:6/100 Iteration 5 Validation Accuracy is : 0.23160763084888458
# Epoch:6/100 Iteration 10/10 Training loss is : 3.05493426322937
# Epoch:6/100 Iteration 10 Validation Accuracy is : 0.23160763084888458
# Epoch:7/100 Iteration 5/10 Training loss is : 3.291640281677246
# Epoch:7/100 Iteration 5 Validation Accuracy is : 0.2261580377817154
# Epoch:7/100 Iteration 10/10 Training loss is : 2.9694039821624756
# Epoch:7/100 Iteration 10 Validation Accuracy is : 0.2261580377817154
# Epoch:8/100 Iteration 5/10 Training loss is : 3.201057195663452
# Epoch:8/100 Iteration 5 Validation Accuracy is : 0.23160763084888458
# Epoch:8/100 Iteration 10/10 Training loss is : 2.8893823623657227
# Epoch:8/100 Iteration 10 Validation Accuracy is : 0.23160763084888458
# Epoch:9/100 Iteration 5/10 Training loss is : 3.11502742767334
# Epoch:9/100 Iteration 5 Validation Accuracy is : 0.23160763084888458
# Epoch:9/100 Iteration 10/10 Training loss is : 2.813981056213379
# Epoch:9/100 Iteration 10 Validation Accuracy is : 0.23433242738246918
# Epoch:10/100 Iteration 5/10 Training loss is : 3.0344467163085938
# Epoch:10/100 Iteration 5 Validation Accuracy is : 0.23705722391605377
# Epoch:10/100 Iteration 10/10 Training loss is : 2.7442543506622314
# Epoch:10/100 Iteration 10 Validation Accuracy is : 0.23705722391605377
# Epoch:11/100 Iteration 5/10 Training loss is : 2.9583170413970947
# Epoch:11/100 Iteration 5 Validation Accuracy is : 0.23705722391605377
# Epoch:11/100 Iteration 10/10 Training loss is : 2.6789958477020264
# Epoch:11/100 Iteration 10 Validation Accuracy is : 0.24250681698322296
# Epoch:12/100 Iteration 5/10 Training loss is : 2.887126922607422
# Epoch:12/100 Iteration 5 Validation Accuracy is : 0.24250681698322296
# Epoch:12/100 Iteration 10/10 Training loss is : 2.6186914443969727
# Epoch:12/100 Iteration 10 Validation Accuracy is : 0.23978202044963837
# Epoch:13/100 Iteration 5/10 Training loss is : 2.821052312850952
# Epoch:13/100 Iteration 5 Validation Accuracy is : 0.24250681698322296
# Epoch:13/100 Iteration 10/10 Training loss is : 2.562199592590332
# Epoch:13/100 Iteration 10 Validation Accuracy is : 0.23978202044963837
# Epoch:14/100 Iteration 5/10 Training loss is : 2.7590129375457764
# Epoch:14/100 Iteration 5 Validation Accuracy is : 0.23705722391605377
# Epoch:14/100 Iteration 10/10 Training loss is : 2.5091683864593506
# Epoch:14/100 Iteration 10 Validation Accuracy is : 0.23705722391605377
# Epoch:15/100 Iteration 5/10 Training loss is : 2.6997201442718506
# Epoch:15/100 Iteration 5 Validation Accuracy is : 0.23978202044963837
# Epoch:15/100 Iteration 10/10 Training loss is : 2.4588921070098877
# Epoch:15/100 Iteration 10 Validation Accuracy is : 0.24795641005039215
# Epoch:16/100 Iteration 5/10 Training loss is : 2.6436100006103516
# Epoch:16/100 Iteration 5 Validation Accuracy is : 0.24795641005039215
# Epoch:16/100 Iteration 10/10 Training loss is : 2.41194224357605
# Epoch:16/100 Iteration 10 Validation Accuracy is : 0.25068119168281555
# Epoch:17/100 Iteration 5/10 Training loss is : 2.590663433074951
# Epoch:17/100 Iteration 5 Validation Accuracy is : 0.25340598821640015
# Epoch:17/100 Iteration 10/10 Training loss is : 2.367933511734009
# Epoch:17/100 Iteration 10 Validation Accuracy is : 0.25885558128356934
# Epoch:18/100 Iteration 5/10 Training loss is : 2.541259288787842
# Epoch:18/100 Iteration 5 Validation Accuracy is : 0.25613078474998474
# Epoch:18/100 Iteration 10/10 Training loss is : 2.326801300048828
# Epoch:18/100 Iteration 10 Validation Accuracy is : 0.25340598821640015
# Epoch:19/100 Iteration 5/10 Training loss is : 2.495060920715332
# Epoch:19/100 Iteration 5 Validation Accuracy is : 0.25340598821640015
# Epoch:19/100 Iteration 10/10 Training loss is : 2.288658857345581
# Epoch:19/100 Iteration 10 Validation Accuracy is : 0.25613078474998474
# Epoch:20/100 Iteration 5/10 Training loss is : 2.451821804046631
# Epoch:20/100 Iteration 5 Validation Accuracy is : 0.25885558128356934
# Epoch:20/100 Iteration 10/10 Training loss is : 2.2527458667755127
# Epoch:20/100 Iteration 10 Validation Accuracy is : 0.25885558128356934
# Epoch:21/100 Iteration 5/10 Training loss is : 2.41088604927063
# Epoch:21/100 Iteration 5 Validation Accuracy is : 0.25340598821640015
# Epoch:21/100 Iteration 10/10 Training loss is : 2.218271017074585
# Epoch:21/100 Iteration 10 Validation Accuracy is : 0.26158037781715393
# Epoch:22/100 Iteration 5/10 Training loss is : 2.3721210956573486
# Epoch:22/100 Iteration 5 Validation Accuracy is : 0.25885558128356934
# Epoch:22/100 Iteration 10/10 Training loss is : 2.185885429382324
# Epoch:22/100 Iteration 10 Validation Accuracy is : 0.26158037781715393
# Epoch:23/100 Iteration 5/10 Training loss is : 2.3354928493499756
# Epoch:23/100 Iteration 5 Validation Accuracy is : 0.2643051743507385
# Epoch:23/100 Iteration 10/10 Training loss is : 2.155278444290161
# Epoch:23/100 Iteration 10 Validation Accuracy is : 0.2643051743507385
# Epoch:24/100 Iteration 5/10 Training loss is : 2.3013689517974854
# Epoch:24/100 Iteration 5 Validation Accuracy is : 0.2697547674179077
# Epoch:24/100 Iteration 10/10 Training loss is : 2.1270999908447266
# Epoch:24/100 Iteration 10 Validation Accuracy is : 0.2697547674179077
# Epoch:25/100 Iteration 5/10 Training loss is : 2.2693357467651367
# Epoch:25/100 Iteration 5 Validation Accuracy is : 0.2724795639514923
# Epoch:25/100 Iteration 10/10 Training loss is : 2.1005771160125732
# Epoch:25/100 Iteration 10 Validation Accuracy is : 0.2724795639514923
# Epoch:26/100 Iteration 5/10 Training loss is : 2.2393460273742676
# Epoch:26/100 Iteration 5 Validation Accuracy is : 0.2724795639514923
# Epoch:26/100 Iteration 10/10 Training loss is : 2.0755929946899414
# Epoch:26/100 Iteration 10 Validation Accuracy is : 0.2724795639514923
# Epoch:27/100 Iteration 5/10 Training loss is : 2.210599660873413
# Epoch:27/100 Iteration 5 Validation Accuracy is : 0.2861035466194153
# Epoch:27/100 Iteration 10/10 Training loss is : 2.052011251449585
# Epoch:27/100 Iteration 10 Validation Accuracy is : 0.2833787500858307
# Epoch:28/100 Iteration 5/10 Training loss is : 2.1830644607543945
# Epoch:28/100 Iteration 5 Validation Accuracy is : 0.2833787500858307
# Epoch:28/100 Iteration 10/10 Training loss is : 2.0297155380249023
# Epoch:28/100 Iteration 10 Validation Accuracy is : 0.2833787500858307
# Epoch:29/100 Iteration 5/10 Training loss is : 2.1564204692840576
# Epoch:29/100 Iteration 5 Validation Accuracy is : 0.2888283431529999
# Epoch:29/100 Iteration 10/10 Training loss is : 2.0085220336914062
# Epoch:29/100 Iteration 10 Validation Accuracy is : 0.2861035466194153
# Epoch:30/100 Iteration 5/10 Training loss is : 2.13098406791687
# Epoch:30/100 Iteration 5 Validation Accuracy is : 0.2861035466194153
# Epoch:30/100 Iteration 10/10 Training loss is : 1.988676905632019
# Epoch:30/100 Iteration 10 Validation Accuracy is : 0.2861035466194153
# Epoch:31/100 Iteration 5/10 Training loss is : 2.1068005561828613
# Epoch:31/100 Iteration 5 Validation Accuracy is : 0.2888283431529999
# Epoch:31/100 Iteration 10/10 Training loss is : 1.969773530960083
# Epoch:31/100 Iteration 10 Validation Accuracy is : 0.2861035466194153
# Epoch:32/100 Iteration 5/10 Training loss is : 2.08341646194458
# Epoch:32/100 Iteration 5 Validation Accuracy is : 0.2861035466194153
# Epoch:32/100 Iteration 10/10 Training loss is : 1.9517914056777954
# Epoch:32/100 Iteration 10 Validation Accuracy is : 0.2861035466194153
# Epoch:33/100 Iteration 5/10 Training loss is : 2.0606682300567627
# Epoch:33/100 Iteration 5 Validation Accuracy is : 0.2861035466194153
# Epoch:33/100 Iteration 10/10 Training loss is : 1.9346997737884521
# Epoch:33/100 Iteration 10 Validation Accuracy is : 0.2861035466194153
# Epoch:34/100 Iteration 5/10 Training loss is : 2.0387680530548096
# Epoch:34/100 Iteration 5 Validation Accuracy is : 0.2888283431529999
# Epoch:34/100 Iteration 10/10 Training loss is : 1.9184374809265137
# Epoch:34/100 Iteration 10 Validation Accuracy is : 0.2888283431529999
# Epoch:35/100 Iteration 5/10 Training loss is : 2.0175859928131104
# Epoch:35/100 Iteration 5 Validation Accuracy is : 0.2861035466194153
# Epoch:35/100 Iteration 10/10 Training loss is : 1.9030263423919678
# Epoch:35/100 Iteration 10 Validation Accuracy is : 0.2861035466194153
# Epoch:36/100 Iteration 5/10 Training loss is : 1.9970890283584595
# Epoch:36/100 Iteration 5 Validation Accuracy is : 0.2861035466194153
# Epoch:36/100 Iteration 10/10 Training loss is : 1.888510823249817
# Epoch:36/100 Iteration 10 Validation Accuracy is : 0.2861035466194153
# Epoch:37/100 Iteration 5/10 Training loss is : 1.9776517152786255
# Epoch:37/100 Iteration 5 Validation Accuracy is : 0.2915531396865845
# Epoch:37/100 Iteration 10/10 Training loss is : 1.8747718334197998
# Epoch:37/100 Iteration 10 Validation Accuracy is : 0.2915531396865845
# Epoch:38/100 Iteration 5/10 Training loss is : 1.9593112468719482
# Epoch:38/100 Iteration 5 Validation Accuracy is : 0.29427793622016907
# Epoch:38/100 Iteration 10/10 Training loss is : 1.8619284629821777
# Epoch:38/100 Iteration 10 Validation Accuracy is : 0.29427793622016907
# Epoch:39/100 Iteration 5/10 Training loss is : 1.941956639289856
# Epoch:39/100 Iteration 5 Validation Accuracy is : 0.29700273275375366
# Epoch:39/100 Iteration 10/10 Training loss is : 1.8493709564208984
# Epoch:39/100 Iteration 10 Validation Accuracy is : 0.29427793622016907
# Epoch:40/100 Iteration 5/10 Training loss is : 1.9254142045974731
# Epoch:40/100 Iteration 5 Validation Accuracy is : 0.29700273275375366
# Epoch:40/100 Iteration 10/10 Training loss is : 1.8374851942062378
# Epoch:40/100 Iteration 10 Validation Accuracy is : 0.29972752928733826
# Epoch:41/100 Iteration 5/10 Training loss is : 1.909674882888794
# Epoch:41/100 Iteration 5 Validation Accuracy is : 0.29972752928733826
# Epoch:41/100 Iteration 10/10 Training loss is : 1.8260821104049683
# Epoch:41/100 Iteration 10 Validation Accuracy is : 0.29427793622016907
# Epoch:42/100 Iteration 5/10 Training loss is : 1.894126534461975
# Epoch:42/100 Iteration 5 Validation Accuracy is : 0.29427793622016907
# Epoch:42/100 Iteration 10/10 Training loss is : 1.8147729635238647
# Epoch:42/100 Iteration 10 Validation Accuracy is : 0.2915531396865845
# Epoch:43/100 Iteration 5/10 Training loss is : 1.8791004419326782
# Epoch:43/100 Iteration 5 Validation Accuracy is : 0.29427793622016907
# Epoch:43/100 Iteration 10/10 Training loss is : 1.8037868738174438
# Epoch:43/100 Iteration 10 Validation Accuracy is : 0.2915531396865845
# Epoch:44/100 Iteration 5/10 Training loss is : 1.864691138267517
# Epoch:44/100 Iteration 5 Validation Accuracy is : 0.2915531396865845
# Epoch:44/100 Iteration 10/10 Training loss is : 1.7932252883911133
# Epoch:44/100 Iteration 10 Validation Accuracy is : 0.2888283431529999
# Epoch:45/100 Iteration 5/10 Training loss is : 1.850980520248413
# Epoch:45/100 Iteration 5 Validation Accuracy is : 0.2888283431529999
# Epoch:45/100 Iteration 10/10 Training loss is : 1.7830026149749756
# Epoch:45/100 Iteration 10 Validation Accuracy is : 0.2861035466194153
# Epoch:46/100 Iteration 5/10 Training loss is : 1.8379939794540405
# Epoch:46/100 Iteration 5 Validation Accuracy is : 0.2861035466194153
# Epoch:46/100 Iteration 10/10 Training loss is : 1.7733086347579956
# Epoch:46/100 Iteration 10 Validation Accuracy is : 0.2861035466194153
# Epoch:47/100 Iteration 5/10 Training loss is : 1.8256844282150269
# Epoch:47/100 Iteration 5 Validation Accuracy is : 0.2833787500858307
# Epoch:47/100 Iteration 10/10 Training loss is : 1.7641059160232544
# Epoch:47/100 Iteration 10 Validation Accuracy is : 0.2833787500858307
# Epoch:48/100 Iteration 5/10 Training loss is : 1.813881278038025
# Epoch:48/100 Iteration 5 Validation Accuracy is : 0.2806539535522461
# Epoch:48/100 Iteration 10/10 Training loss is : 1.755313754081726
# Epoch:48/100 Iteration 10 Validation Accuracy is : 0.2833787500858307
# Epoch:49/100 Iteration 5/10 Training loss is : 1.802417516708374
# Epoch:49/100 Iteration 5 Validation Accuracy is : 0.2833787500858307
# Epoch:49/100 Iteration 10/10 Training loss is : 1.7471041679382324
# Epoch:49/100 Iteration 10 Validation Accuracy is : 0.2833787500858307
# Epoch:50/100 Iteration 5/10 Training loss is : 1.7917500734329224
# Epoch:50/100 Iteration 5 Validation Accuracy is : 0.2833787500858307
# Epoch:50/100 Iteration 10/10 Training loss is : 1.7393437623977661
# Epoch:50/100 Iteration 10 Validation Accuracy is : 0.2888283431529999
# Epoch:51/100 Iteration 5/10 Training loss is : 1.7817332744598389
# Epoch:51/100 Iteration 5 Validation Accuracy is : 0.2888283431529999
# Epoch:51/100 Iteration 10/10 Training loss is : 1.7320713996887207
# Epoch:51/100 Iteration 10 Validation Accuracy is : 0.2888283431529999
# Epoch:52/100 Iteration 5/10 Training loss is : 1.772050142288208
# Epoch:52/100 Iteration 5 Validation Accuracy is : 0.2833787500858307
# Epoch:52/100 Iteration 10/10 Training loss is : 1.7250300645828247
# Epoch:52/100 Iteration 10 Validation Accuracy is : 0.2861035466194153
# Epoch:53/100 Iteration 5/10 Training loss is : 1.7627619504928589
# Epoch:53/100 Iteration 5 Validation Accuracy is : 0.2915531396865845
# Epoch:53/100 Iteration 10/10 Training loss is : 1.7184076309204102
# Epoch:53/100 Iteration 10 Validation Accuracy is : 0.2861035466194153
# Epoch:54/100 Iteration 5/10 Training loss is : 1.753933072090149
# Epoch:54/100 Iteration 5 Validation Accuracy is : 0.2861035466194153
# Epoch:54/100 Iteration 10/10 Training loss is : 1.7121469974517822
# Epoch:54/100 Iteration 10 Validation Accuracy is : 0.2833787500858307
# Epoch:55/100 Iteration 5/10 Training loss is : 1.745579481124878
# Epoch:55/100 Iteration 5 Validation Accuracy is : 0.2833787500858307
# Epoch:55/100 Iteration 10/10 Training loss is : 1.7061405181884766
# Epoch:55/100 Iteration 10 Validation Accuracy is : 0.2833787500858307
# Epoch:56/100 Iteration 5/10 Training loss is : 1.737403392791748
# Epoch:56/100 Iteration 5 Validation Accuracy is : 0.2833787500858307
# Epoch:56/100 Iteration 10/10 Training loss is : 1.7003076076507568
# Epoch:56/100 Iteration 10 Validation Accuracy is : 0.2833787500858307
# Epoch:57/100 Iteration 5/10 Training loss is : 1.7296563386917114
# Epoch:57/100 Iteration 5 Validation Accuracy is : 0.2833787500858307
# Epoch:57/100 Iteration 10/10 Training loss is : 1.6947590112686157
# Epoch:57/100 Iteration 10 Validation Accuracy is : 0.2833787500858307
# Epoch:58/100 Iteration 5/10 Training loss is : 1.7223408222198486
# Epoch:58/100 Iteration 5 Validation Accuracy is : 0.2861035466194153
# Epoch:58/100 Iteration 10/10 Training loss is : 1.6895267963409424
# Epoch:58/100 Iteration 10 Validation Accuracy is : 0.2861035466194153
# Epoch:59/100 Iteration 5/10 Training loss is : 1.7153071165084839
# Epoch:59/100 Iteration 5 Validation Accuracy is : 0.2833787500858307
# Epoch:59/100 Iteration 10/10 Training loss is : 1.6843714714050293
# Epoch:59/100 Iteration 10 Validation Accuracy is : 0.2833787500858307
# Epoch:60/100 Iteration 5/10 Training loss is : 1.7085788249969482
# Epoch:60/100 Iteration 5 Validation Accuracy is : 0.2833787500858307
# Epoch:60/100 Iteration 10/10 Training loss is : 1.6794956922531128
# Epoch:60/100 Iteration 10 Validation Accuracy is : 0.2833787500858307
# Epoch:61/100 Iteration 5/10 Training loss is : 1.7020745277404785
# Epoch:61/100 Iteration 5 Validation Accuracy is : 0.2833787500858307
# Epoch:61/100 Iteration 10/10 Training loss is : 1.6748535633087158
# Epoch:61/100 Iteration 10 Validation Accuracy is : 0.2833787500858307
# Epoch:62/100 Iteration 5/10 Training loss is : 1.6958577632904053
# Epoch:62/100 Iteration 5 Validation Accuracy is : 0.2833787500858307
# Epoch:62/100 Iteration 10/10 Training loss is : 1.6703547239303589
# Epoch:62/100 Iteration 10 Validation Accuracy is : 0.2806539535522461
# Epoch:63/100 Iteration 5/10 Training loss is : 1.6898772716522217
# Epoch:63/100 Iteration 5 Validation Accuracy is : 0.2779291570186615
# Epoch:63/100 Iteration 10/10 Training loss is : 1.6660300493240356
# Epoch:63/100 Iteration 10 Validation Accuracy is : 0.2779291570186615
# Epoch:64/100 Iteration 5/10 Training loss is : 1.6841959953308105
# Epoch:64/100 Iteration 5 Validation Accuracy is : 0.2779291570186615
# Epoch:64/100 Iteration 10/10 Training loss is : 1.6619147062301636
# Epoch:64/100 Iteration 10 Validation Accuracy is : 0.2779291570186615
# Epoch:65/100 Iteration 5/10 Training loss is : 1.6788071393966675
# Epoch:65/100 Iteration 5 Validation Accuracy is : 0.2752043604850769
# Epoch:65/100 Iteration 10/10 Training loss is : 1.6579720973968506
# Epoch:65/100 Iteration 10 Validation Accuracy is : 0.2752043604850769
# Epoch:66/100 Iteration 5/10 Training loss is : 1.6736969947814941
# Epoch:66/100 Iteration 5 Validation Accuracy is : 0.2752043604850769
# Epoch:66/100 Iteration 10/10 Training loss is : 1.654187798500061
# Epoch:66/100 Iteration 10 Validation Accuracy is : 0.2752043604850769
# Epoch:67/100 Iteration 5/10 Training loss is : 1.6688742637634277
# Epoch:67/100 Iteration 5 Validation Accuracy is : 0.2752043604850769
# Epoch:67/100 Iteration 10/10 Training loss is : 1.650570273399353
# Epoch:67/100 Iteration 10 Validation Accuracy is : 0.2779291570186615
# Epoch:68/100 Iteration 5/10 Training loss is : 1.6643521785736084
# Epoch:68/100 Iteration 5 Validation Accuracy is : 0.2779291570186615
# Epoch:68/100 Iteration 10/10 Training loss is : 1.6470800638198853
# Epoch:68/100 Iteration 10 Validation Accuracy is : 0.2779291570186615
# Epoch:69/100 Iteration 5/10 Training loss is : 1.6600213050842285
# Epoch:69/100 Iteration 5 Validation Accuracy is : 0.2779291570186615
# Epoch:69/100 Iteration 10/10 Training loss is : 1.6437100172042847
# Epoch:69/100 Iteration 10 Validation Accuracy is : 0.2724795639514923
# Epoch:70/100 Iteration 5/10 Training loss is : 1.6558454036712646
# Epoch:70/100 Iteration 5 Validation Accuracy is : 0.2752043604850769
# Epoch:70/100 Iteration 10/10 Training loss is : 1.6404777765274048
# Epoch:70/100 Iteration 10 Validation Accuracy is : 0.2752043604850769
# Epoch:71/100 Iteration 5/10 Training loss is : 1.6519160270690918
# Epoch:71/100 Iteration 5 Validation Accuracy is : 0.2779291570186615
# Epoch:71/100 Iteration 10/10 Training loss is : 1.6373534202575684
# Epoch:71/100 Iteration 10 Validation Accuracy is : 0.2779291570186615
# Epoch:72/100 Iteration 5/10 Training loss is : 1.6481332778930664
# Epoch:72/100 Iteration 5 Validation Accuracy is : 0.2779291570186615
# Epoch:72/100 Iteration 10/10 Training loss is : 1.6342905759811401
# Epoch:72/100 Iteration 10 Validation Accuracy is : 0.2779291570186615
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-a8fce3d97a72> in <module>()
#      10         for x, y in get_batches(train_x, train_y, n_batch):
#      11             feed_dict = {inputs_: x, labels_: y}
# ---> 12             loss, _ = sess.run([cost,optimizer], feed_dict=feed_dict)
#      13             iteration += 1
#      14
#
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/ww/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Testing
#
# Below you see the test accuracy. You can also see the predictions returned for images.

# %%
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    feed = {inputs_: test_x,
            labels_: test_y}
    test_acc = sess.run(accuracy, feed_dict=feed)
    print("Test accuracy: {:.4f}".format(test_acc))

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from scipy.ndimage import imread

# %% [markdown]
# Below, feel free to choose images and see how the trained classifier predicts the flowers in them.

# %%
test_img_path = 'flower_photos/roses/10894627425_ec76bbc757_n.jpg'
test_img = imread(test_img_path)
plt.imshow(test_img)

# %%
# Run this cell if you don't have a vgg graph built
if 'vgg' in globals():
    print('"vgg" object already exists.  Will not create again.')
else:
    #create vgg
    with tf.Session() as sess:
        input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
        vgg = vgg16.Vgg16()
        vgg.build(input_)

# %%
with tf.Session() as sess:
    img = utils.load_image(test_img_path)
    img = img.reshape((1, 224, 224, 3))

    feed_dict = {input_: img}
    code = sess.run(vgg.relu6, feed_dict=feed_dict)
        
saver = tf.train.Saver()
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    feed = {inputs_: code}
    prediction = sess.run(predicted, feed_dict=feed).squeeze()

# %%
plt.imshow(test_img)

# %%
plt.barh(np.arange(5), prediction)
_ = plt.yticks(np.arange(5), lb.classes_)
